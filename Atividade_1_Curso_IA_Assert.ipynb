# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizWalker/Curso_Assert_IA_IoT/blob/main/Atividade_1_Curso_IA_Assert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn import metrics

import pandas as pd

#url = "https://raw.githubusercontent.com/tmoura/machinelearning/master/datasets/transfusion.data" #dataset 1
url = "https://raw.githubusercontent.com/tmoura/machinelearning/master/datasets/sonar.data" #dataset 2

# Carregar base de dados
# DataFrame
dataset = pd.read_csv(url, header=None)

columns = len(dataset.columns)

y = dataset[0] # extrai a primeira coluna, que é o label
X = dataset.loc[:,1:columns-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None, stratify=y) # 80% treino e 20% teste

# %%
# Treinamendo da Árvore de Decisão
#model = tree.DecisionTreeClassifier(criterion="entropy",max_depth=2)
model = tree.DecisionTreeClassifier(criterion="entropy")
model = model.fit(X_train, y_train)

# %%
# Predição e Resultados

result = model.predict(X_test)
acc = metrics.accuracy_score(result, y_test)
show = round(acc * 100)
print("{}%".format(show))

print(list(result))
print(list(y_test))
# Out:
# 74%
# [2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2, 2, 1, 1, 1, 1, 1, 2, 1, 2, 1, 2, 2, 2, 2, 2, 1, 1, 1, 1, 2, 2]
# [1, 2, 1, 2, 2, 1, 2, 1, 1, 1, 1, 2, 1, 2, 1, 1, 2, 2, 2, 1, 2, 2, 1, 2, 2, 1, 1, 1, 2, 2, 1, 2, 2, 2, 2, 2, 1, 1, 1, 1, 2, 2]

# %%
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.5362318840579711, 0.95, 'x[11] <= 0.169\nentropy = 0.996\nsamples = 166\nvalue = [77, 89]'),
#  Text(0.30434782608695654, 0.85, 'x[46] <= 0.11\nentropy = 0.665\nsamples = 52\nvalue = [43, 9]'),
#  Text(0.18840579710144928, 0.75, 'x[21] <= 0.999\nentropy = 0.183\nsamples = 36\nvalue = [35, 1]'),
#  Text(0.13043478260869565, 0.65, 'entropy = 0.0\nsamples = 35\nvalue = [35, 0]'),
#  Text(0.2463768115942029, 0.65, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42028985507246375, 0.75, 'x[33] <= 0.355\nentropy = 1.0\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.36231884057971014, 0.65, 'x[18] <= 0.766\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.30434782608695654, 0.55, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.42028985507246375, 0.55, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4782608695652174, 0.65, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7681159420289855, 0.85, 'x[27] <= 0.895\nentropy = 0.879\nsamples = 114\nvalue = [34, 80]'),
#  Text(0.6521739130434783, 0.75, 'x[53] <= 0.02\nentropy = 0.975\nsamples = 81\nvalue = [33, 48]'),
#  Text(0.5942028985507246, 0.65, 'x[44] <= 0.324\nentropy = 1.0\nsamples = 66\nvalue = [33, 33]'),
#  Text(0.5362318840579711, 0.55, 'x[35] <= 0.523\nentropy = 0.986\nsamples = 58\nvalue = [33, 25]'),
#  Text(0.37681159420289856, 0.45, 'x[22] <= 0.785\nentropy = 0.985\nsamples = 42\nvalue = [18, 24]'),
#  Text(0.2318840579710145, 0.35, 'x[52] <= 0.014\nentropy = 0.931\nsamples = 26\nvalue = [17, 9]'),
#  Text(0.11594202898550725, 0.25, 'x[51] <= 0.012\nentropy = 0.629\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.057971014492753624, 0.15, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.17391304347826086, 0.15, 'x[6] <= 0.129\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.11594202898550725, 0.05, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2318840579710145, 0.05, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.34782608695652173, 0.25, 'x[6] <= 0.224\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.2898550724637681, 0.15, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.4057971014492754, 0.15, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5217391304347826, 0.35, 'x[21] <= 0.614\nentropy = 0.337\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.463768115942029, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5797101449275363, 0.25, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.6956521739130435, 0.45, 'x[58] <= 0.031\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.6376811594202898, 0.35, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.7536231884057971, 0.35, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6521739130434783, 0.55, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.7101449275362319, 0.65, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.8840579710144928, 0.75, 'x[7] <= 0.244\nentropy = 0.196\nsamples = 33\nvalue = [1, 32]'),
#  Text(0.8260869565217391, 0.65, 'entropy = 0.0\nsamples = 32\nvalue = [0, 32]'),
#  Text(0.9420289855072463, 0.65, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]')]
