# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizWalker/Curso_Assert_IA_IoT/blob/main/Atividade_2_Curso_IA_Assert_Transfusion_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/tmoura/machinelearning/master/transfusion.data"
dataset = pd.read_csv(url, header=None)
dataset
# Out:
#      0   1   2      3   4
# 0    1   2  50  12500  98
# 1    1   0  13   3250  28
# 2    1   1  16   4000  35
# 3    1   2  20   5000  45
# 4    2   1  24   6000  77
# ..  ..  ..  ..    ...  ..
# 743  2  23   2    500  38
# 744  2  21   2    500  52
# 745  2  23   3    750  62
# 746  2  39   1    250  39
# 747  2  72   1    250  72
#
# [748 rows x 5 columns]

# %% [markdown]
# #Normalização dos atributos

# %%
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()

dataset[[0]] = mms.fit_transform(dataset[[0]])
dataset[[1]] = mms.fit_transform(dataset[[1]])
dataset[[2]] = mms.fit_transform(dataset[[2]])
dataset[[3]] = mms.fit_transform(dataset[[3]])
dataset[[4]] = mms.fit_transform(dataset[[4]])

dataset
# Out:
#        0         1         2         3         4
# 0    0.0  0.027027  1.000000  1.000000  1.000000
# 1    0.0  0.000000  0.244898  0.244898  0.270833
# 2    0.0  0.013514  0.306122  0.306122  0.343750
# 3    0.0  0.027027  0.387755  0.387755  0.447917
# 4    1.0  0.013514  0.469388  0.469388  0.781250
# ..   ...       ...       ...       ...       ...
# 743  1.0  0.310811  0.020408  0.020408  0.375000
# 744  1.0  0.283784  0.020408  0.020408  0.520833
# 745  1.0  0.310811  0.040816  0.040816  0.625000
# 746  1.0  0.527027  0.000000  0.000000  0.385417
# 747  1.0  0.972973  0.000000  0.000000  0.729167
#
# [748 rows x 5 columns]

# %% [markdown]
# #Label Encoder

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

dataset[0] = label_encoder.fit_transform(dataset[0])

# %%
dataset
# Out:
#      0         1         2         3         4
# 0    0  0.027027  1.000000  1.000000  1.000000
# 1    0  0.000000  0.244898  0.244898  0.270833
# 2    0  0.013514  0.306122  0.306122  0.343750
# 3    0  0.027027  0.387755  0.387755  0.447917
# 4    1  0.013514  0.469388  0.469388  0.781250
# ..  ..       ...       ...       ...       ...
# 743  1  0.310811  0.020408  0.020408  0.375000
# 744  1  0.283784  0.020408  0.020408  0.520833
# 745  1  0.310811  0.040816  0.040816  0.625000
# 746  1  0.527027  0.000000  0.000000  0.385417
# 747  1  0.972973  0.000000  0.000000  0.729167
#
# [748 rows x 5 columns]

# %% [markdown]
# #Separar Conjunto de Treino e Teste

# %%
y = dataset[0]

X = dataset.drop([0], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None,stratify=y)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

model1 = DecisionTreeClassifier(criterion="entropy")
model2 = KNeighborsClassifier(n_neighbors=7, metric='euclidean',algorithm='brute')

model3 = DecisionTreeClassifier(criterion="log_loss", max_depth=64, splitter="best")
model4 = KNeighborsClassifier(n_neighbors=5, metric='minkowski',algorithm='ball_tree')


model1.fit(X_train, y_train)
model2.fit(X_train, y_train)
model3.fit(X_train, y_train)
model4.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree')

# %%
from sklearn import metrics

result1 = model1.predict(X_test)
result2 = model2.predict(X_test)
result3 = model3.predict(X_test)
result4 = model4.predict(X_test)

acc1 = metrics.accuracy_score(result1, y_test)
show1 = round(acc1 * 100)
print("Resultado modelo 1(em %): ", format(show1))

acc2 = metrics.accuracy_score(result2, y_test)
show2 = round(acc2 * 100)
print("Resultado modelo 2(em %): ", format(show2))

acc3 = metrics.accuracy_score(result3, y_test)
show3 = round(acc3 * 100)
print("Resultado modelo 3(em %): ", format(show3))

acc4 = metrics.accuracy_score(result4, y_test)
show4 = round(acc4 * 100)
print("Resultado modelo 4(em %): ", format(show4))
# Out:
# Resultado modelo 1(em %):  73
# Resultado modelo 2(em %):  79
# Resultado modelo 3(em %):  75
# Resultado modelo 4(em %):  77
